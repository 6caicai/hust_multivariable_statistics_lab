# %%
#ex1
def count_cap(string):
    length = len(string)
    count = 0
    for i in range(length):
        if (string[i] == string[i].upper()):
            count += 1
    return count

count_cap("foDFWhj")
# Out:
# 3

# %%
#ex2
#part1
def inner_product(x_vals, y_vals):
    listA = list(zip(a, b))
    sum = 0
    for i in listA:
        sum += i[0] * i[1]
    return sum

a = [1, 2, 4]
b = [2, 4, 2]
inner_product(a, b)
# Out:
# 18

# %%
#part2
print(len([x for x in range(999) if x % 2 == 0]))
# Out:
# 500

# %%
#part3
pairs=((2,5),(4,2),(9,8),(12,10))
print(len([i for i in pairs if i[0] % 2 == 0 and i[1] % 2 == 0]))
# Out:
# 2

# %%
#ex3
import numpy as np

# Parameters
mu = 1
sigma = 1
sample_size = 10000

# Generate a large sample
sample = np.random.normal(mu, sigma, sample_size)

# Estimate the coefficient of variation
coefficient_of_variation = np.std(sample) / np.mean(sample)
print(coefficient_of_variation)
# Out:
# 1.0024593653106832

# %%
import matplotlib.pyplot as plt

# Function to estimate coefficient of variation for different sample sizes
def estimate_coefficient_of_variation(sample_sizes, mu, sigma):
    estimates = []
    for size in sample_sizes:
        sample = np.random.normal(mu, sigma, size)
        cv = np.std(sample) / np.mean(sample)
        estimates.append(cv)
    return estimates

# Sample sizes to test
sample_sizes = np.arange(100, 10001, 100)

# Estimate coefficient of variation for different sample sizes
estimates = estimate_coefficient_of_variation(sample_sizes, mu, sigma)

# Plot the estimates
plt.plot(sample_sizes, estimates, label='Estimated Coefficient of Variation')
plt.axhline(y=sigma/mu, color='r', linestyle='--', label='True Coefficient of Variation')
plt.xlabel('Sample Size')
plt.ylabel('Coefficient of Variation')
plt.legend()
plt.show()

# %%
ticker_list = { "INTC": "Intel",
                "MSFT": "Microsoft",
                "IBM": "IBM",
                "BHP": "BHP",
                "TM": "Toyota",
                "AAPL": "Apple",
                "AMZN": "Amazon",
                "BA": "Boeing",
                "QCOM": "Qualcomm",
                "KO": "Coca-Cola",
                "GOOG": "Google",
                "SNE": "Sony",
                "PTR": "PetroChina"}

# %%
import pandas as pd
df = pd.read_csv("ticker_data.csv")

# %%
times = len(df)
price_former = sum([df[x][0] for x in df if x in ticker_list])
for i in range(1, times):
    price_present = sum([df[x][i] for x in df if x in ticker_list]) 
    print(f"the {i} day percentage change is: {price_present/price_former*100}")
    price_former = price_present
# Out:
# the 1 day percentage change is: 99.6380484328329
# the 2 day percentage change is: 99.96007478191797
# the 3 day percentage change is: 99.83936152296849
# the 4 day percentage change is: 99.57401420946921
# the 5 day percentage change is: 100.12582658307288
# the 6 day percentage change is: 100.49870005540207
# the 7 day percentage change is: 99.74552720945981
# the 8 day percentage change is: 98.7028229429696
# the 9 day percentage change is: 99.31993856830131
# the 10 day percentage change is: 100.17947612700513
# the 11 day percentage change is: 100.06136498234599
# the 12 day percentage change is: 99.67547313948056
# the 13 day percentage change is: 100.0925094127417
# the 14 day percentage change is: 102.39812089028099
# the 15 day percentage change is: 98.10496649461415
# the 16 day percentage change is: 99.9526566240641
# the 17 day percentage change is: 99.8422683941041
# the 18 day percentage change is: 99.94674480741233
# the 19 day percentage change is: 100.44195630609885
# the 20 day percentage change is: 99.70933252773449
# the 21 day percentage change is: 101.2393829522986
# the 22 day percentage change is: 98.04974429740135
# the 23 day percentage change is: 101.52691925087221
# the 24 day percentage change is: 100.04968808854755
# the 25 day percentage change is: 100.46736826709417
# the 26 day percentage change is: 101.04955633527099
# the 27 day percentage change is: 99.81305872768911
# the 28 day percentage change is: 99.32785460863313
# the 29 day percentage change is: 100.460819601905
# the 30 day percentage change is: 100.16313797476472
# the 31 day percentage change is: 99.8007902114285
# the 32 day percentage change is: 100.79711116463884
# the 33 day percentage change is: 98.53241706337667
# the 34 day percentage change is: 99.75396950844228
# the 35 day percentage change is: 100.7704681071293
# the 36 day percentage change is: 98.40932936909566
# the 37 day percentage change is: 100.56617870074516
# the 38 day percentage change is: 100.77700053982119
# the 39 day percentage change is: 99.86386363338613
# the 40 day percentage change is: 99.89588391888331
# the 41 day percentage change is: 100.56308581036883
# the 42 day percentage change is: 101.7074730654519
# the 43 day percentage change is: 99.55179963815671
# the 44 day percentage change is: 100.36173563418693
# the 45 day percentage change is: 100.11539275317428
# the 46 day percentage change is: 100.4372839284079
# the 47 day percentage change is: 99.32307228806344
# the 48 day percentage change is: 99.95283333454252
# the 49 day percentage change is: 99.82293168357778
# the 50 day percentage change is: 99.9310436021339
# the 51 day percentage change is: 99.7682454548869
# the 52 day percentage change is: 99.97607440894704
# the 53 day percentage change is: 100.35374193204973
# the 54 day percentage change is: 99.33966571827222
# the 55 day percentage change is: 100.63068198365819
# the 56 day percentage change is: 99.77402866933518
# the 57 day percentage change is: 100.53686082241089
# the 58 day percentage change is: 99.29607941820746
# the 59 day percentage change is: 99.30851200191833
# the 60 day percentage change is: 99.18706070789978
# the 61 day percentage change is: 100.74489205124746
# the 62 day percentage change is: 99.31502674394802
# the 63 day percentage change is: 99.58865377171891
# the 64 day percentage change is: 98.9480942787463
# the 65 day percentage change is: 100.16858815208272
# the 66 day percentage change is: 100.48610959135718
# the 67 day percentage change is: 101.44994632262336
# the 68 day percentage change is: 100.26784318778246
# the 69 day percentage change is: 99.7087878977037
# the 70 day percentage change is: 98.1821860909017
# the 71 day percentage change is: 101.5141892224945
# the 72 day percentage change is: 97.76898703687257
# the 73 day percentage change is: 98.18906162998184
# the 74 day percentage change is: 101.16223580726698
# the 75 day percentage change is: 100.48823013731716
# the 76 day percentage change is: 101.23812416355673
# the 77 day percentage change is: 100.55216985060378
# the 78 day percentage change is: 100.4395769667414
# the 79 day percentage change is: 99.0884802504748
# the 80 day percentage change is: 101.53272874157526
# the 81 day percentage change is: 101.13252282237329
# the 82 day percentage change is: 99.00733750760516
# the 83 day percentage change is: 101.1328198582221
# the 84 day percentage change is: 101.43961457555126
# the 85 day percentage change is: 101.06534795451265
# the 86 day percentage change is: 100.11162766143586
# the 87 day percentage change is: 101.31903002886217
# the 88 day percentage change is: 99.48434022573409
# the 89 day percentage change is: 100.51707470397898
# the 90 day percentage change is: 100.00625603545595
# the 91 day percentage change is: 100.28678472305477
# the 92 day percentage change is: 100.62804605162903
# the 93 day percentage change is: 99.49400947545053
# the 94 day percentage change is: 100.89839420977694
# the 95 day percentage change is: 100.3546760328732
# the 96 day percentage change is: 99.99917765530557
# the 97 day percentage change is: 98.7002774787741
# the 98 day percentage change is: 99.39018399476603
# the 99 day percentage change is: 99.3918725368433
# the 100 day percentage change is: 100.66062800705615
# the 101 day percentage change is: 99.2284084400606
# the 102 day percentage change is: 100.6630766856408
# the 103 day percentage change is: 99.47721889815261
# the 104 day percentage change is: 100.03699535933441
# the 105 day percentage change is: 99.48180535030365
# the 106 day percentage change is: 99.25647280105564
# the 107 day percentage change is: 100.09363438798955
# the 108 day percentage change is: 101.5036016336303
# the 109 day percentage change is: 100.5014557882288
# the 110 day percentage change is: 98.94623734149278
# the 111 day percentage change is: 99.02432414448738
# the 112 day percentage change is: 100.94274458958998
# the 113 day percentage change is: 99.03908697573249
# the 114 day percentage change is: 101.23875564192927
# the 115 day percentage change is: 101.0424310101327
# the 116 day percentage change is: 98.86515627628548
# the 117 day percentage change is: 97.963872497804
# the 118 day percentage change is: 99.79769524208481
# the 119 day percentage change is: 98.40281974897853
# the 120 day percentage change is: 100.24186827227662
# the 121 day percentage change is: 100.56372791779755
# the 122 day percentage change is: 100.31933106150935
# the 123 day percentage change is: 100.26468789531424
# the 124 day percentage change is: 101.1844940942604
# the 125 day percentage change is: 100.3210066322395
# the 126 day percentage change is: 100.40539050637149
# the 127 day percentage change is: 100.4240694383515
# the 128 day percentage change is: 100.51499452511268
# the 129 day percentage change is: 100.42305009035535
# the 130 day percentage change is: 100.15865367717262
# the 131 day percentage change is: 101.82496475029883
# the 132 day percentage change is: 100.08556060900706
# the 133 day percentage change is: 100.26177963497254
# the 134 day percentage change is: 99.8918892532517
# the 135 day percentage change is: 100.27158809783592
# the 136 day percentage change is: 99.72059304331223
# the 137 day percentage change is: 98.75957854700134
# the 138 day percentage change is: 100.75434452871778
# the 139 day percentage change is: 99.46023139536216
# the 140 day percentage change is: 100.52288739971655
# the 141 day percentage change is: 99.53730986427216
# the 142 day percentage change is: 100.25696252621694
# the 143 day percentage change is: 99.52812208308667
# the 144 day percentage change is: 100.55389210653163
# the 145 day percentage change is: 99.6329084310412
# the 146 day percentage change is: 101.52246019011473
# the 147 day percentage change is: 100.61569937465815
# the 148 day percentage change is: 99.81662131262166
# the 149 day percentage change is: 99.1348417821903
# the 150 day percentage change is: 99.25954321020237
# the 151 day percentage change is: 100.10116459527526
# the 152 day percentage change is: 99.72967891029947
# the 153 day percentage change is: 100.44612603340136
# the 154 day percentage change is: 100.83086470405725
# the 155 day percentage change is: 99.62662811433404
# the 156 day percentage change is: 99.04184149040235
# the 157 day percentage change is: 99.97279562402619
# the 158 day percentage change is: 100.44776776963067
# the 159 day percentage change is: 99.6026630117543
# the 160 day percentage change is: 99.73913633407169
# the 161 day percentage change is: 100.64828921157773
# the 162 day percentage change is: 100.00944582544035
# the 163 day percentage change is: 99.6843324002544
# the 164 day percentage change is: 98.1790777972115
# the 165 day percentage change is: 99.88801275126522
# the 166 day percentage change is: 100.5009358141421
# the 167 day percentage change is: 99.18445334608012
# the 168 day percentage change is: 101.37786374815047
# the 169 day percentage change is: 101.14307604649694
# the 170 day percentage change is: 100.33111556571998
# the 171 day percentage change is: 100.20022471152004
# the 172 day percentage change is: 101.23001388950303
# the 173 day percentage change is: 99.84458420801893
# the 174 day percentage change is: 99.18532548104425
# the 175 day percentage change is: 99.98125024083797
# the 176 day percentage change is: 99.72765518916229
# the 177 day percentage change is: 99.54784852409901
# the 178 day percentage change is: 100.54701624987314
# the 179 day percentage change is: 102.00175614570321
# the 180 day percentage change is: 99.92992676599816
# the 181 day percentage change is: 99.72711979307049
# the 182 day percentage change is: 100.16272860429697
# the 183 day percentage change is: 99.99438446299186
# the 184 day percentage change is: 99.18241634937928
# the 185 day percentage change is: 100.66778871494047
# the 186 day percentage change is: 99.39249063980566
# the 187 day percentage change is: 99.25860555922725
# the 188 day percentage change is: 101.34806191537547
# the 189 day percentage change is: 100.04179010251477
# the 190 day percentage change is: 98.7953514815
# the 191 day percentage change is: 100.21182777869714
# the 192 day percentage change is: 99.19626565235849
# the 193 day percentage change is: 98.62081728387906
# the 194 day percentage change is: 100.46988894297515
# the 195 day percentage change is: 101.62804445402713
# the 196 day percentage change is: 100.62835520415618
# the 197 day percentage change is: 100.42866522172913
# the 198 day percentage change is: 99.93207715240881
# the 199 day percentage change is: 101.28218452583151
# the 200 day percentage change is: 99.4210275645991
# the 201 day percentage change is: 105.78349197680348
# the 202 day percentage change is: 100.00717539414603
# the 203 day percentage change is: 100.6116286074586
# the 204 day percentage change is: 100.84206809980152
# the 205 day percentage change is: 100.27834388295149
# the 206 day percentage change is: 100.69207659193368
# the 207 day percentage change is: 99.9439805192327
# the 208 day percentage change is: 100.67184888825244
# the 209 day percentage change is: 100.03699448942933
# the 210 day percentage change is: 99.8330375087481
# the 211 day percentage change is: 99.70732714202629
# the 212 day percentage change is: 100.2596915865025
# the 213 day percentage change is: 99.62357932664382
# the 214 day percentage change is: 99.97532481049828
# the 215 day percentage change is: 98.27607829643058
# the 216 day percentage change is: 101.08548282135163
# the 217 day percentage change is: 99.95327998161378
# the 218 day percentage change is: 99.89315943123512
# the 219 day percentage change is: 101.21362631575013
# the 220 day percentage change is: 100.90297052122294
# the 221 day percentage change is: 100.23454424229917
# the 222 day percentage change is: 99.8051828604252
# the 223 day percentage change is: 99.73901859935069
# the 224 day percentage change is: 99.41653489160254
# the 225 day percentage change is: 100.89078196369401
# the 226 day percentage change is: 99.99200491745462
# the 227 day percentage change is: 100.45312683977814
# the 228 day percentage change is: 100.92855896557322
# the 229 day percentage change is: 100.90281750130549
# the 230 day percentage change is: 100.50472820757155
# the 231 day percentage change is: 99.40097225070656
# the 232 day percentage change is: 100.0174200359338
# the 233 day percentage change is: 100.10380022371017
# the 234 day percentage change is: 99.9896993696721
# the 235 day percentage change is: 100.6676798609484
# the 236 day percentage change is: 100.32845162785118
# the 237 day percentage change is: 100.12904799597482
# the 238 day percentage change is: 98.96997594077779
# the 239 day percentage change is: 99.53161342897178
# the 240 day percentage change is: 99.5144356719486
# the 241 day percentage change is: 100.93753919581023
# the 242 day percentage change is: 99.59858133482709
# the 243 day percentage change is: 101.03484242923255
# the 244 day percentage change is: 99.6638792919591
# the 245 day percentage change is: 101.01743545211302
# the 246 day percentage change is: 101.38483961687497
# the 247 day percentage change is: 99.76779684132889
# the 248 day percentage change is: 100.50012418314915
# the 249 day percentage change is: 99.6750206015498
# the 250 day percentage change is: 99.35898794144832
# the 251 day percentage change is: 100.93605750575779
